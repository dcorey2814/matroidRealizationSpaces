# %%
using Oscar
using Combinatorics
pm = Polymake


include("../../src/matroid_realization.jl");
include("../../src/reduceIdealsv2.jl")
include("../../src/JacobianCriterion.jl")
d3n11 = vec(readlines("../3lines_d3n11.dat"));
g = "0**00*0000*0000************0**********0***************0***********0***********0*****0***********************0********0*******************************0****************00********"
# Out:
# "0**00*0000*0000************0**********0***************0***********0***********0*****0***********************0********0*******************************0****************00********"

# %%
f = "0**00*0000*0000************0**********0***************0***********0***********0*****0***********************0********0*******************************0****************00********"
# Out:
# "0**00*0000*0000************0**********0***************0***********0***********0*****0***********************0********0*******************************0****************00********"

# %%
M = matroid_from_revlex_basis_encoding(f[12:176],3,11)
# Out:
# Matroid of rank 3 on 11 elements

# %%
I = matroid_to_reduced_expression_min_chart(M,QQ)
# Out:
# (fmpq_mpoly[4*x_{1, 6}^9 + 20*x_{1, 6}^8*x_{1, 7} - 24*x_{1, 6}^8 + 64*x_{1, 6}^7*x_{1, 7}^2 - 106*x_{1, 6}^7*x_{1, 7} + 57*x_{1, 6}^7 + 144*x_{1, 6}^6*x_{1, 7}^3 - 304*x_{1, 6}^6*x_{1, 7}^2 + 216*x_{1, 6}^6*x_{1, 7} - 67*x_{1, 6}^6 + 224*x_{1, 6}^5*x_{1, 7}^4 - 592*x_{1, 6}^5*x_{1, 7}^3 + 546*x_{1, 6}^5*x_{1, 7}^2 - 205*x_{1, 6}^5*x_{1, 7} + 39*x_{1, 6}^5 + 256*x_{1, 6}^4*x_{1, 7}^5 - 776*x_{1, 6}^4*x_{1, 7}^4 + 892*x_{1, 6}^4*x_{1, 7}^3 - 448*x_{1, 6}^4*x_{1, 7}^2 + 80*x_{1, 6}^4*x_{1, 7} - 9*x_{1, 6}^4 + 192*x_{1, 6}^3*x_{1, 7}^6 - 720*x_{1, 6}^3*x_{1, 7}^5 + 956*x_{1, 6}^3*x_{1, 7}^4 - 582*x_{1, 6}^3*x_{1, 7}^3 + 149*x_{1, 6}^3*x_{1, 7}^2 + x_{1, 6}^3*x_{1, 7} + 64*x_{1, 6}^2*x_{1, 7}^7 - 384*x_{1, 6}^2*x_{1, 7}^6 + 696*x_{1, 6}^2*x_{1, 7}^5 - 498*x_{1, 6}^2*x_{1, 7}^4 + 131*x_{1, 6}^2*x_{1, 7}^3 - x_{1, 6}^2*x_{1, 7}^2 - 6*x_{1, 6}^2*x_{1, 7} - 64*x_{1, 6}*x_{1, 7}^7 + 240*x_{1, 6}*x_{1, 7}^6 - 280*x_{1, 6}*x_{1, 7}^5 + 96*x_{1, 6}*x_{1, 7}^4 + 14*x_{1, 6}*x_{1, 7}^3 - 6*x_{1, 6
# ...

# %%
simplified_2_singular_locus(I[1],I[2],true)
# Out:
# ideal(1)

# %%
binomial(11,3)
# Out:
# 165

# %%
length(f)
# Out:
# 176

# %%
stuck_ideal = [3605,3613,3622,3786,5856]
stuck_jacobian= [3786]

# %%
stuck = [3605,3613,3622,3786,3786]
# Out:
# 5-element Vector{Int64}:
#  3605
#  3613
#  3622
#  3786
#  3786
